# %% [markdown]
# # Unir tablas y localizaciones
# Este notebooke es para concentrar y hacer un merge con de la localizacion de las estaciones con las localizaciones de las estaciones de monitoreo

# %%
import pandas as pd
import geopandas as gpd 
import shapely

# %% [markdown]
# ## Carga de datos
#
# Vamos a leer los datos

# %%
estaciones = gpd.read_file('../../../Contaminantes/Estaciones_ubicacion.csv')
estaciones.geometry = estaciones.apply(lambda l: shapely.geometry.Point(float(l.Longitud), float(l.Latitud)), axis=1 )
estaciones.set_crs('EPSG:4326', inplace=True)
estaciones['Altitud']= estaciones['Altitud'].apply(lambda l: int(l.split()[0]))
estaciones.head()
# Out:
# /home/miguel/miniconda3/envs/data/lib/python3.10/site-packages/pandas/core/dtypes/cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#   Estacion              Localidad              Estado    Latitud    Longitud  \
# 0     ACO                 Acolman  Estado de México    19.635501  -98.912003
# 1     AJU                Tlalpan                CDMX   19.154674  -99.162459
# 2     AJM                Tlalpan                CDMX     19.2721  -99.207658
# 3     ATI   Atizapán de Zaragoza    Estado de México   19.576963  -99.254133
# 4     BJU          Benito Juárez                CDMX   19.371612  -99.158969
#
#    Altitud                    geometry
# 0     2198  POINT (-98.91200 19.63550)
# 1     2953  POINT (-99.16246 19.15467)
# 2     2619  POINT (-99.20766 19.27210)
# 3     2341  POINT (-99.25413 19.57696)
# 4     2250  POINT (-99.15897 19.37161)

# %%
estaciones.plot(aspect=1)
# Out:
# <AxesSubplot: >

# %%
estaciones.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %% [markdown]
# Solo nos vamos a quedar con las del valle de mexico y que no sean NaN

# %%
contaminantes = pd.read_csv('../../../Contaminantes/PM25/PM_25.csv')
contaminantes = contaminantes[contaminantes.CVE_EST.apply(lambda l: 'ZMVM' in l) ] ### keep mexico central Valley 
#contaminantes = contaminantes.dropna('VALOR',axis=1) ### Drop Nan
#contaminantes = contaminantes.drop('Unnamed:0') ## remove column
contaminantes.reset_index(drop=True,inplace =True)
# Out:
#            index  Unnamed: 0   CVE_EST       FECHA  HORA PARAMETRO  VALOR  \
# 0              0           1  ACO_ZMVM  2004-01-01     1     pm2.5    NaN
# 1              1           2  ACO_ZMVM  2004-01-01     2     pm2.5    NaN
# 2              2           3  ACO_ZMVM  2004-01-01     3     pm2.5    NaN
# 3              3           4  ACO_ZMVM  2004-01-01     4     pm2.5    NaN
# 4              4           5  ACO_ZMVM  2004-01-01     5     pm2.5    NaN
# ...          ...         ...       ...         ...   ...       ...    ...
# 2781251  5361045     5361046  XAL_ZMVM  2021-12-31    20     pm2.5    NaN
# 2781252  5361046     5361047  XAL_ZMVM  2021-12-31    21     pm2.5    NaN
# 2781253  5361047     5361048  XAL_ZMVM  2021-12-31    22     pm2.5    NaN
# 2781254  5361048     5361049  XAL_ZMVM  2021-12-31    23     pm2.5    NaN
# 2781255  5361049     5361050  XAL_ZMVM  2021-12-31    24     pm2.5    NaN
#
#                    UNIDAD
# 0        µg/m<sup>3</sup>
# 1        µg/m<sup>3</sup>
# 2        µg/m<sup>3</sup>
# 3        µg/m<sup>3</sup>
# 4        µg/m<sup>3</sup>
# ...                   ...
# 2781251  µg/m<sup>3</sup>
# 2781252  µg/m<sup>3</sup>
# 2781253  µg/m<sup>3</sup>
# 2781254  µg/m<sup>3</sup>
# 2781255  µg/m<sup>3</sup>
#
# [2781256 rows x 8 columns]

# %%
contaminantes.head()
# Out:
#    Unnamed: 0   CVE_EST       FECHA  HORA PARAMETRO  VALOR            UNIDAD
# 0           1  ACO_ZMVM  2004-01-01     1     pm2.5    NaN  µg/m<sup>3</sup>
# 1           2  ACO_ZMVM  2004-01-01     2     pm2.5    NaN  µg/m<sup>3</sup>
# 2           3  ACO_ZMVM  2004-01-01     3     pm2.5    NaN  µg/m<sup>3</sup>
# 3           4  ACO_ZMVM  2004-01-01     4     pm2.5    NaN  µg/m<sup>3</sup>
# 4           5  ACO_ZMVM  2004-01-01     5     pm2.5    NaN  µg/m<sup>3</sup>

# %%
contaminantes.VALOR.isna()
# Out:
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
#            ...
# 5361045    True
# 5361046    True
# 5361047    True
# 5361048    True
# 5361049    True
# Name: VALOR, Length: 2781256, dtype: bool

# %%
# Out:
#          Unnamed: 0   CVE_EST       FECHA  HORA PARAMETRO  VALOR  \
# 0                 1  ACO_ZMVM  2004-01-01     1     pm2.5    NaN
# 1                 2  ACO_ZMVM  2004-01-01     2     pm2.5    NaN
# 2                 3  ACO_ZMVM  2004-01-01     3     pm2.5    NaN
# 3                 4  ACO_ZMVM  2004-01-01     4     pm2.5    NaN
# 4                 5  ACO_ZMVM  2004-01-01     5     pm2.5    NaN
# ...             ...       ...         ...   ...       ...    ...
# 5361045     5361046  XAL_ZMVM  2021-12-31    20     pm2.5    NaN
# 5361046     5361047  XAL_ZMVM  2021-12-31    21     pm2.5    NaN
# 5361047     5361048  XAL_ZMVM  2021-12-31    22     pm2.5    NaN
# 5361048     5361049  XAL_ZMVM  2021-12-31    23     pm2.5    NaN
# 5361049     5361050  XAL_ZMVM  2021-12-31    24     pm2.5    NaN
#
#                    UNIDAD
# 0        µg/m<sup>3</sup>
# 1        µg/m<sup>3</sup>
# 2        µg/m<sup>3</sup>
# 3        µg/m<sup>3</sup>
# 4        µg/m<sup>3</sup>
# ...                   ...
# 5361045  µg/m<sup>3</sup>
# 5361046  µg/m<sup>3</sup>
# 5361047  µg/m<sup>3</sup>
# 5361048  µg/m<sup>3</sup>
# 5361049  µg/m<sup>3</sup>
#
# [2781256 rows x 7 columns]
